# %% [markdown]
# **Aufgabe 2: Lade den ganzen Text von [Friedrich Glausers Wachtmeister Studer](http://gutenberg.spiegel.de/autor/friedrich-glauser-201) herunter, und speichere die Texte Kapitel für Kapitel als Pandas Dataframe an.**

# %% [markdown]
# Die Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# Der Code

# %%
url = "http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/1"
response = requests.get(url)
glauser = BeautifulSoup(response.text, 'html.parser')

# %%
urlbase = "http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/"

# %%
urlbase + "1"
# Out:
# 'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/1'

# %%
urlbase + "2"
# Out:
# 'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/2'

# %%
numlist = range(1,23)

# %%
urllist = []
for i in numlist:
    url = urlbase + str(i)
    urllist.append(url)

# %%
urllist
# Out:
# ['http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/1',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/2',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/3',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/4',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/5',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/6',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/7',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/8',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/9',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/10',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/11',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/12',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/13',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/14',
#  'http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/15',
# ...

# %%
url = urllist[0]
response = requests.get(url)
glauser = BeautifulSoup(response.text, 'html.parser')

# %%
glauser.find('div', {'id': 'gutenb'}).find('h3').text
# Out:
# 'Einer will nicht mehr mitmachen'

# %%
glauser.find('div', {'id': 'gutenb'}).text
# Out:
# "\n\nEiner will nicht mehr mitmachen\nDer Gefangenenwärter mit dem dreifachen Kinn und der roten Nase brummte etwas von »ewigem G'stürm«, – weil ihn Studer vom Mittagessen wegholte. Aber Studer war immerhin ein Fahnderwachtmeister von der Berner Kantonspolizei, und so konnte man ihn nicht ohne weiteres zum Teufel jagen.\nDer Wärter Liechti stand also auf, füllte sein Wasserglas mit Rotwein, leerte es auf einen Zug, nahm einen Schlüsselbund und kam mit zum Häftling Schlumpf, den der Wachtmeister vor knapp einer Stunde eingeliefert hatte.\nGänge… Dunkle lange Gänge… Die Mauern waren dick. Das Schloß Thun schien für Ewigkeiten gebaut. Überall hockte noch die Kälte des Winters.\nEs war schwer, sich vorzustellen, daß draußen ein warmer Maientag über dem See lag, daß in der Sonne Leute spazieren gingen, unbeschwert, daß andere in Booten auf dem Wasser schaukelten und sich die Haut braun brennen ließen.\nDie Zellentüre ging auf. Studer blieb einen Augenblick auf der Schwelle stehen. Zwei wa
# ...

# %%
urllist

# %%
url = stellvertreter
response = requests.get(url)
glauser = BeautifulSoup(response.text, 'html.parser')

# %%
glauser.find('div', {'id': 'gutenb'}).find('h3').text

# %%
glauser.find('div', {'id': 'gutenb'}).text

# %%
new_lst = []
for i in urllist:
    print(i)
    
    url = i
    response = requests.get(url)
    glauser = BeautifulSoup(response.text, 'html.parser')
    
    kapitel = glauser.find('div', {'id': 'gutenb'}).find('h3').text
    text = glauser.find('div', {'id': 'gutenb'}).text
    
    mini_dict = {'Kapitel': kapitel,
                 'Text': text}
    
    new_lst.append(mini_dict)
# Out:
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/1
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/2
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/3
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/4
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/5
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/6
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/7
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/8
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/9
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/10
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/11
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/12
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/13
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/14
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/15
# http://gutenberg.spiegel.de/buch/wachtmeister-studer-1857/16
# ...

# %%
pd.DataFrame(new_lst)
# Out:
#                                              Kapitel  \
# 0                    Einer will nicht mehr mitmachen
# 1               Der Fall Wendelin Witschi zum ersten
# 2                 Billard und Alkoholismus chronicus
# 3                  Felicitas Rose und Parker Duofold
# 4                     Läden, Lautsprecher, Landjäger
# 5          Noch einer, der nicht mehr mitmachen will
# 6                                Zimmer zu vermieten
# 7                      Interieur der Familie Witschi
# 8              Der Fall Wendelin Witschi zum zweiten
# 9                                  Der Daumenabdruck
# 10                                  The Convict Band
# 11                              Witschis Schießstand
# 12                  Anastasia Witschi, geb. Mischler
# 13                                           Schwomm
# 14                                 Liebe vor Gericht
# 15  Der Fall Witschi zum dritten und vorletzten Male
# 16                                      Der Autodieb
# ...

# %%
glauser
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="de">
# <!-- Template 413170.html generated Mon Nov 20 06:40:41 2017 -->
# <head>
# <title>Friedrich Glauser Leben und Werk - Projekt Gutenberg</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="SPIEGEL ONLINE, Hamburg, Germany" name="author"/>
# <meta content="SPIEGEL ONLINE, Hamburg, Germany" name="copyright"/>
# <meta content="spiegel_online@spiegel.de" name="email"/>
# <meta content="true" name="MSSmartTagsPreventParsing"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="2006-04-26T16:34:00+0200" name="date"/>
# <meta content="2006-04-26T16:34:00+0200" name="last-modified"/>
# <meta content="de_DE" property="og:locale"/>
# <meta content="false" name="spnet.relatedboxuse"/>
# ...
