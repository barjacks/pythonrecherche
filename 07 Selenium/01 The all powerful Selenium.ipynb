# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup

# %% [markdown]
# [Dokumentation](http://selenium-python.readthedocs.io/)

# %%
driver = webdriver.Firefox()
search_url = "https://dnszensur.ch/censorship_phishing.php"
driver.get(search_url)

# %%
text = (driver.page_source)

# %%
soup = BeautifulSoup(text, 'html.parser')

# %%
soup
# Out:
# <html lang="de"><head>
# <meta charset="utf-8">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <title>DNSzensur.ch</title>
# <meta content="Markus Ritzmann" name="author">
# <meta content="Schweizer Internet Anbieter wie Swisscom und UPC sperren gewisse Webseiten mittels DNS-Server. DNSzensur.ch überprüft regelmässig Tausende von Domains und findet gesperrte Webseiten." name="description">
# <meta content="summary" name="twitter:card">
# <meta content="@DNSzensur" name="twitter:site">
# <meta content="DNS Zensur in der Schweiz" name="twitter:title">
# <meta content="Auch Schweizer Internet Provider zensieren das Web." name="twitter:description">
# <meta content="https://dnszensur.ch/src/img/sm_header.png" name="twitter:image">
# <meta content="https://dnszensur.ch/censorship_phishing.php" property="og:url">
# <meta content="article" property="og:type">
# ...

# %%
for elem in soup.find_all('td', {'style': ''}):
    print(elem.text)
# Out:
# 125xc.com
#
#
# 4dle.info
#
#
# 9c40a04e9732e6a6.com
#
#
# a-blog.eu
#
#
# a9-project.com
#
#
# ab913aa797e78b3.com
#
#
# abraji.org.br
#
#
# actressytzqcvihnk.top
#
#
# aestrych.win
#
#
# afforcedpvpuvfd.download
#
#
# africanbeauty.top
#
#
# aggressorqildemna.website
#
#
# agonistazcpv.download
#
#
# allaprizes.party
#
#
# allegesinqpnoe.top
#
#
# allextension4upgrade.site
#
#
# allextensionforupdates.download
#
#
# allodqvyxxn.top
#
#
# allupdatingyouwilleverneed.review
#
#
# allupgradesyouwilleverneed.stream
#
#
# alreadybest2updates.stream
#
#
# alreadybest4update.stream
#
#
# alreadybestforupdate.download
#
#
# alwaysbetterforupdates.website
#
#
# alwaysdebug2update.website
#
#
# alwaysdebug4update.website
#
#
# amptb.pro
#
#
# anagogesnqvajy.website
#
#
# androidweb.xyz
#
#
# animecrave.com
#
#
# antonymousplxmqcfvs.download
#
#
# apple-mac.pro
#
#
# appraisingemfxg.download
#
#
# appstate.mobi
#
#
# arcadeagenda.win
#
#
# arcreqz.top
#
#
# arskit-wd.com
#
#
# atomcurve.com
#
# ...

# %%
driver.find_element_by_class_name('dropdown-menu')
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="12dbe46d-46e9-f04b-a147-cd3dab7fd27d", element="9df67561-d76f-8c42-853a-74bee6e9d602")>

# %%
test = driver.find_element_by_class_name('dropdown-menu')
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="12dbe46d-46e9-f04b-a147-cd3dab7fd27d", element="9df67561-d76f-8c42-853a-74bee6e9d602")>

# %%
test.find_element_by_partial_link_text('Phishing').click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-18-2275c36462ca> in <module>()
# ----> 1 test.find_element_by_partial_link_text('Phishing').click()
#
# ~/.virtualenvs/master/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      75     def click(self):
#      76         """Clicks the element."""
# ---> 77         self._execute(Command.CLICK_ELEMENT)
#      78
#      79     def submit(self):
#
# ~/.virtualenvs/master/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     491             params = {}
#     492         params['id'] = self._id
# --> 493         return self._parent.execute(command, params)
#     494
#     495     def find_element(self, by=By.ID, value=None):
#
# ...
